# %%
# import necessary libraries
import warnings
warnings.filterwarnings("ignore")
import nltk
from nltk.stem import WordNetLemmatizer
import json
import pickle

import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import SGD
import random
from keras.models import load_model

# create an object of WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# importing the GL Bot corpus file for pre-processing

words=[]
classes = []
documents = []
ignore_words = ['?', '!']
data_file = open("intents.json").read()
intents = json.loads(data_file)

# %%
# preprocessing the json data
# tokenization
#nltk.download('punkt')
#nltk.download('wordnet')
for intent in intents['intents']:
    for pattern in intent['patterns']:

        #tokenize each word
        w = nltk.word_tokenize(pattern)
        words.extend(w)
        #add documents in the corpus
        documents.append((w, intent['tag']))

        # add to our classes list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

# %%
# lemmatize, lower each word and remove duplicates

words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))

# sort classes
classes = sorted(list(set(classes)))

# documents = combination between patterns and intents
print (len(documents), "documents")

# classes = intents
print (len(classes), "classes", classes)

# words = all words, vocabulary
print (len(words), "unique lemmatized words", words)

# creating a pickle file to store the Python objects which we will use while predicting
pickle.dump(words,open('texts.pkl','wb')) 
pickle.dump(classes,open('labels.pkl','wb'))
# Out:
# 75 documents
# 38 classes ['goodbye', 'greeting', 'manfaat_IISMA', 'manfaat_PMMB', 'manfaat_kampus_mengajar', 'manfaat_magang', 'manfaat_pejuang_muda', 'manfaat_pertukaran_mahasiswa', 'manfaat_studi_independen', 'mitra_IISMA', 'mitra_PMMB', 'mitra_magang', 'mitra_studi_independen', 'penjelasan_IISMA', 'penjelasan_PMMB', 'penjelasan_kampus_mengajar', 'penjelasan_kampus_merdeka', 'penjelasan_magang', 'penjelasan_pejuang_muda', 'penjelasan_pertukaran_mahasiswa', 'penjelasan_studi_independen', 'periode_dan_pendaftaran_IISMA', 'periode_dan_pendaftaran_PMMB', 'periode_dan_pendaftaran_kampus_mengajar', 'periode_dan_pendaftaran_magang', 'periode_dan_pendaftaran_pejuang_muda', 'periode_dan_pendaftaran_pertukaran_mahasiswa', 'periode_dan_pendaftaran_studi_independen', 'persyaratan_IISMA', 'persyaratan_kampus_mengajar', 'persyaratan_kampus_merdeka', 'persyaratan_magang', 'persyaratan_pejuang_muda', 'persyaratan_pertukaran_mahasiswa', 'persyaratan_studi_independen', 'program_kampus_merdeka', 'terimakasih', 'tujuan_kampus_merdeka']
# 69 unique lemmatized words ['afternoon', 'apa', 'apabila', 'bagaimana', 'bai', 'banyak', 'bersertifikat', 'bro', 'bumn', 'bye', 'byee', 'cara', 'dadah', 'dah', 'dalam', 'dan', 'good', 'hai', 'hallo', 'halo', 'hei', 'hi', 'hy', 'iisma', 'independen', 'itu', 'jumpa', 'kampus', 'kasih', 'kawan', 'kemendikbud', 'kemensos', 'magang', 'mahasiswa', 'makasih', 'malam', 'manfaat', 'mendaftar', 'mengajar', 'mengikuti', 'merdeka', 'mitra', 'morning', 'muda', 'pagi', 'pejuang', 'pelaksanaan', 'periode', 'persyaratan', 'pertukaran', 'pmmb', 'program', 'saja', 'sampai', 'see', 'selamat', 'si', 'siang', 'sore', 'studi', 'tergabung', 'terima', 'thank', 'thanks', 'tinggal', 'tujuan', 'universitas', 'yang', 'you']

# %%
# create our training data
training = []

# create an empty array for our output
output_empty = [0] * len(classes)

# training set, bag of words for each sentence
for doc in documents:
    # initialize our bag of words
    bag = []
    # list of tokenized words for the pattern
    pattern_words = doc[0]
   
    # lemmatize each word - create base word, in attempt to represent related words
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    
    # create our bag of words array with 1, if word match found in current pattern
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)
    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1
    training.append([bag, output_row])

# shuffle features and converting it into numpy arrays
random.shuffle(training)
training = np.array(training)

# create train and test lists
train_x = list(training[:,0])
train_y = list(training[:,1])

print("Training data created")
# Out:
# Training data created

# %%
# Create NN model to predict the responses
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

# Compile model. Stochastic gradient descent with Nesterov accelerated gradient gives good results for this model
sgd = SGD(learning_rate=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

#fitting and saving the model 
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('model.h5', hist) # we will pickle this model to use in the future
print("\n")
print("*"*50)
print("\nModel Created Successfully!")
# Out:
# Epoch 1/200
# 15/15 [==============================] - 1s 2ms/step - loss: 3.6102 - accuracy: 0.0400
# Epoch 2/200
# 15/15 [==============================] - 0s 2ms/step - loss: 3.4298 - accuracy: 0.2133
# Epoch 3/200
# 15/15 [==============================] - 0s 2ms/step - loss: 3.3213 - accuracy: 0.2400
# Epoch 4/200
# 15/15 [==============================] - 0s 6ms/step - loss: 3.2052 - accuracy: 0.2533
# Epoch 5/200
# 15/15 [==============================] - 0s 2ms/step - loss: 2.9457 - accuracy: 0.2533
# Epoch 6/200
# 15/15 [==============================] - 0s 3ms/step - loss: 2.7999 - accuracy: 0.2667
# Epoch 7/200
# 15/15 [==============================] - 0s 3ms/step - loss: 2.6736 - accuracy: 0.2400
# Epoch 8/200
# 15/15 [==============================] - 0s 4ms/step - loss: 2.5986 - accuracy: 0.2800
# Epoch 9/200
# 15/15 [==============================] - 0s 2ms/step - loss: 2.4697 - accuracy: 0.2667
# Epoch 10/200
# 15/15 [==============================] - 0s 3ms/step - loss: 2.3283 - accuracy: 0.2933
# Epoch 11/200
# 15/15 [==============================] - 0s 3ms/step - loss: 2.4330 - accuracy: 0.2667
# Epoch 12/200
# 15/15 [==============================] - 0s 2ms/step - loss: 2.2651 - accuracy: 0.3333
# Epoch 13/200
# 15/15 [==============================] - 0s 3ms/step - loss: 2.1612 - accuracy: 0.3200
# Epoch 14/200
# 15/15 [==============================] - 0s 2ms/step - loss: 2.1687 - accuracy: 0.2800
# Epoch 15/200
# 15/15 [==============================] - 0s 2ms/step - loss: 1.9467 - accuracy: 0.3867
# Epoch 16/200
# 15/15 [==============================] - 0s 2ms/step - loss: 1.9577 - accuracy: 0.3733
# Epoch 17/200
# 15/15 [==============================] - 0s 2ms/step - loss: 2.1198 - accuracy: 0.3600
# Epoch 18/200
# 15/15 [==============================] - 0s 2ms/step - loss: 1.8265 - accuracy: 0.4000
# Epoch 19/200
# 15/15 [==============================] - 0s 2ms/step - loss: 1.6292 - accuracy: 0.5200
# Epoch 20/200
# 15/15 [==============================] - 0s 2ms/step - loss: 1.8765 - accuracy: 0.4267
# Epoch 21/200
# 15/15 [==============================] - 0s 2ms/step - loss: 1.6328 - accuracy: 0.4667
# Epoch 22/200
# 15/15 [==============================] - 0s 2ms/step - loss: 1.6693 - accuracy: 0.4667
# Epoch 23/200
# 15/15 [==============================] - 0s 2ms/step - loss: 1.6399 - accuracy: 0.4267
# Epoch 24/200
# 15/15 [==============================] - 0s 2ms/step - loss: 1.5496 - accuracy: 0.5600
# Epoch 25/200
# 15/15 [==============================] - 0s 2ms/step - loss: 1.3879 - accuracy: 0.6000
# Epoch 26/200
# 15/15 [==============================] - 0s 2ms/step - loss: 1.6358 - accuracy: 0.4933
# Epoch 27/200
# 15/15 [==============================] - 0s 2ms/step - loss: 1.3744 - accuracy: 0.5733
# Epoch 28/200
# 15/15 [==============================] - 0s 2ms/step - loss: 1.2167 - accuracy: 0.6400
# Epoch 29/200
# 15/15 [==============================] - 0s 2ms/step - loss: 1.3555 - accuracy: 0.5867
# Epoch 30/200
# 15/15 [==============================] - 0s 2ms/step - loss: 1.3075 - accuracy: 0.5867
# Epoch 31/200
# 15/15 [==============================] - 0s 2ms/step - loss: 1.3119 - accuracy: 0.6133
# Epoch 32/200
# 15/15 [==============================] - 0s 3ms/step - loss: 1.0986 - accuracy: 0.6400
# Epoch 33/200
# 15/15 [==============================] - 0s 4ms/step - loss: 1.2372 - accuracy: 0.5733
# Epoch 34/200
# 15/15 [==============================] - 0s 2ms/step - loss: 1.0387 - accuracy: 0.6933
# Epoch 35/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.9536 - accuracy: 0.7600
# Epoch 36/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.9892 - accuracy: 0.6800
# Epoch 37/200
# 15/15 [==============================] - 0s 3ms/step - loss: 1.0454 - accuracy: 0.6800
# Epoch 38/200
# 15/15 [==============================] - 0s 2ms/step - loss: 1.0061 - accuracy: 0.7067
# Epoch 39/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.8613 - accuracy: 0.7200
# Epoch 40/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.9117 - accuracy: 0.7467
# Epoch 41/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.8809 - accuracy: 0.7467
# Epoch 42/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.9817 - accuracy: 0.6800
# Epoch 43/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.8050 - accuracy: 0.7333
# Epoch 44/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.8507 - accuracy: 0.7333
# Epoch 45/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.9058 - accuracy: 0.7467
# Epoch 46/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.6718 - accuracy: 0.8000
# Epoch 47/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6155 - accuracy: 0.8000
# Epoch 48/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6755 - accuracy: 0.8000
# Epoch 49/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6156 - accuracy: 0.8267
# Epoch 50/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.5972 - accuracy: 0.8400
# Epoch 51/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6326 - accuracy: 0.7867
# Epoch 52/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6946 - accuracy: 0.7867
# Epoch 53/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6918 - accuracy: 0.8267
# Epoch 54/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.5234 - accuracy: 0.8133
# Epoch 55/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.7610 - accuracy: 0.7467
# Epoch 56/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6172 - accuracy: 0.7867
# Epoch 57/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.7929 - accuracy: 0.7067
# Epoch 58/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.5556 - accuracy: 0.8267
# Epoch 59/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4802 - accuracy: 0.8400
# Epoch 60/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4006 - accuracy: 0.8800
# Epoch 61/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.5262 - accuracy: 0.8400
# Epoch 62/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.7017 - accuracy: 0.7600
# Epoch 63/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.5336 - accuracy: 0.8133
# Epoch 64/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4891 - accuracy: 0.8400
# Epoch 65/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.5203 - accuracy: 0.8267
# Epoch 66/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.5515 - accuracy: 0.8000
# Epoch 67/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4856 - accuracy: 0.8933
# Epoch 68/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.5739 - accuracy: 0.8000
# Epoch 69/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4498 - accuracy: 0.8533
# Epoch 70/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4144 - accuracy: 0.8667
# Epoch 71/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4295 - accuracy: 0.8667
# Epoch 72/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6082 - accuracy: 0.8267
# Epoch 73/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4301 - accuracy: 0.8800
# Epoch 74/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.3282 - accuracy: 0.8933
# Epoch 75/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.5383 - accuracy: 0.7867
# Epoch 76/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.3809 - accuracy: 0.8933
# Epoch 77/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.5366 - accuracy: 0.8800
# Epoch 78/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6363 - accuracy: 0.7600
# Epoch 79/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.3057 - accuracy: 0.9200
# Epoch 80/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4676 - accuracy: 0.8133
# Epoch 81/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4036 - accuracy: 0.8667
# Epoch 82/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.3133 - accuracy: 0.9200
# Epoch 83/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4638 - accuracy: 0.8933
# Epoch 84/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4091 - accuracy: 0.8667
# Epoch 85/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.3077 - accuracy: 0.9067
# Epoch 86/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.5342 - accuracy: 0.8133
# Epoch 87/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4534 - accuracy: 0.8133
# Epoch 88/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.3586 - accuracy: 0.8800
# Epoch 89/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.5183 - accuracy: 0.8533
# Epoch 90/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2881 - accuracy: 0.9333
# Epoch 91/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.3593 - accuracy: 0.8533
# Epoch 92/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.3728 - accuracy: 0.8667
# Epoch 93/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4396 - accuracy: 0.8267
# Epoch 94/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4481 - accuracy: 0.8400
# Epoch 95/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.3089 - accuracy: 0.8933
# Epoch 96/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.3287 - accuracy: 0.8933
# Epoch 97/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.3398 - accuracy: 0.8533
# Epoch 98/200
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4846 - accuracy: 0.8533
# Epoch 99/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.3983 - accuracy: 0.8667
# Epoch 100/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.3407 - accuracy: 0.9200
# Epoch 101/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.3392 - accuracy: 0.8533
# Epoch 102/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.3180 - accuracy: 0.8667
# Epoch 103/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2916 - accuracy: 0.9333
# Epoch 104/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.3497 - accuracy: 0.9067
# Epoch 105/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.3275 - accuracy: 0.9200
# Epoch 106/200
# 15/15 [==============================] - 0s 1ms/step - loss: 0.3427 - accuracy: 0.9200
# Epoch 107/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.3825 - accuracy: 0.8667
# Epoch 108/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2723 - accuracy: 0.9200
# Epoch 109/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.4571 - accuracy: 0.8533
# Epoch 110/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.3949 - accuracy: 0.8667
# Epoch 111/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.3952 - accuracy: 0.8933
# Epoch 112/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.3601 - accuracy: 0.9333
# Epoch 113/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4006 - accuracy: 0.8667
# Epoch 114/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2848 - accuracy: 0.9200
# Epoch 115/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2807 - accuracy: 0.8800
# Epoch 116/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.3431 - accuracy: 0.8667
# Epoch 117/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6448 - accuracy: 0.8000
# Epoch 118/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.3384 - accuracy: 0.8933
# Epoch 119/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4702 - accuracy: 0.8800
# Epoch 120/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.3810 - accuracy: 0.8800
# Epoch 121/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.3229 - accuracy: 0.8933
# Epoch 122/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.1757 - accuracy: 0.9600
# Epoch 123/200
# 15/15 [==============================] - 0s 1ms/step - loss: 0.3027 - accuracy: 0.9067
# Epoch 124/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2718 - accuracy: 0.9067
# Epoch 125/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2325 - accuracy: 0.9333
# Epoch 126/200
# 15/15 [==============================] - 0s 1ms/step - loss: 0.3573 - accuracy: 0.8800
# Epoch 127/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.3789 - accuracy: 0.8400
# Epoch 128/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4024 - accuracy: 0.8267
# Epoch 129/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2343 - accuracy: 0.9467
# Epoch 130/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.1823 - accuracy: 0.9600
# Epoch 131/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.3525 - accuracy: 0.8933
# Epoch 132/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2066 - accuracy: 0.9600
# Epoch 133/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.3008 - accuracy: 0.8933
# Epoch 134/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.1931 - accuracy: 0.9333
# Epoch 135/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.3124 - accuracy: 0.8933
# Epoch 136/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2474 - accuracy: 0.9067
# Epoch 137/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.3801 - accuracy: 0.8533
# Epoch 138/200
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4569 - accuracy: 0.8667
# Epoch 139/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.3071 - accuracy: 0.8667
# Epoch 140/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2059 - accuracy: 0.9200
# Epoch 141/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2480 - accuracy: 0.9467
# Epoch 142/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2067 - accuracy: 0.9333
# Epoch 143/200
# 15/15 [==============================] - 0s 1ms/step - loss: 0.2482 - accuracy: 0.9200
# Epoch 144/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2408 - accuracy: 0.9333
# Epoch 145/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2537 - accuracy: 0.9200
# Epoch 146/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2531 - accuracy: 0.9333
# Epoch 147/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2883 - accuracy: 0.8667
# Epoch 148/200
# 15/15 [==============================] - 0s 1ms/step - loss: 0.2118 - accuracy: 0.9333
# Epoch 149/200
# 15/15 [==============================] - ETA: 0s - loss: 0.1034 - accuracy: 1.00 - 0s 2ms/step - loss: 0.1450 - accuracy: 0.9467
# Epoch 150/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2864 - accuracy: 0.8933
# Epoch 151/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2104 - accuracy: 0.9333
# Epoch 152/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2987 - accuracy: 0.9200
# Epoch 153/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2473 - accuracy: 0.9200
# Epoch 154/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2844 - accuracy: 0.9200
# Epoch 155/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.1915 - accuracy: 0.9467
# Epoch 156/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.1920 - accuracy: 0.9733
# Epoch 157/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2887 - accuracy: 0.9067
# Epoch 158/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2346 - accuracy: 0.9467
# Epoch 159/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2295 - accuracy: 0.9467
# Epoch 160/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2109 - accuracy: 0.9200
# Epoch 161/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2985 - accuracy: 0.9067
# Epoch 162/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2900 - accuracy: 0.8933
# Epoch 163/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.3761 - accuracy: 0.8667
# Epoch 164/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2283 - accuracy: 0.9067
# Epoch 165/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.1716 - accuracy: 0.9467
# Epoch 166/200
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4272 - accuracy: 0.8800
# Epoch 167/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.1954 - accuracy: 0.9600
# Epoch 168/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2642 - accuracy: 0.8933
# Epoch 169/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.1103 - accuracy: 0.9867
# Epoch 170/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2432 - accuracy: 0.8933
# Epoch 171/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2390 - accuracy: 0.8933
# Epoch 172/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.3145 - accuracy: 0.9067
# Epoch 173/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.3710 - accuracy: 0.8400
# Epoch 174/200
# 15/15 [==============================] - 0s 1ms/step - loss: 0.2943 - accuracy: 0.8933
# Epoch 175/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2234 - accuracy: 0.9333
# Epoch 176/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.1280 - accuracy: 0.9733
# Epoch 177/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2614 - accuracy: 0.9067
# Epoch 178/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.1817 - accuracy: 0.9200
# Epoch 179/200
# 15/15 [==============================] - 0s 1ms/step - loss: 0.1570 - accuracy: 0.9600
# Epoch 180/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2461 - accuracy: 0.9067
# Epoch 181/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.1459 - accuracy: 0.9600
# Epoch 182/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2399 - accuracy: 0.9200
# Epoch 183/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.3330 - accuracy: 0.8533
# Epoch 184/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2957 - accuracy: 0.8800
# Epoch 185/200
# 15/15 [==============================] - 0s 1ms/step - loss: 0.2473 - accuracy: 0.9333
# Epoch 186/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.3195 - accuracy: 0.9067
# Epoch 187/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.3204 - accuracy: 0.8667
# Epoch 188/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2133 - accuracy: 0.9333
# Epoch 189/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.1945 - accuracy: 0.9467
# Epoch 190/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.1547 - accuracy: 0.9600
# Epoch 191/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2611 - accuracy: 0.9200
# Epoch 192/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2072 - accuracy: 0.9333
# Epoch 193/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2429 - accuracy: 0.9333
# Epoch 194/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2196 - accuracy: 0.9333
# Epoch 195/200
# 15/15 [==============================] - 0s 1ms/step - loss: 0.2571 - accuracy: 0.9200
# Epoch 196/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2028 - accuracy: 0.9333
# Epoch 197/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.1324 - accuracy: 0.9333
# Epoch 198/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.1704 - accuracy: 0.9467
# Epoch 199/200
# 15/15 [==============================] - 0s 1ms/step - loss: 0.1464 - accuracy: 0.9333
# Epoch 200/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2563 - accuracy: 0.9200
#
#
# **************************************************
#
# Model Created Successfully!
