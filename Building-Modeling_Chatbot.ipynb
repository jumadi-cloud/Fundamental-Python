# %% [markdown]
# ### Importing Libraries

# %%
# import necessary libraries
import warnings
warnings.filterwarnings("ignore")
import nltk
from nltk.stem import WordNetLemmatizer
import json
import pickle

import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import SGD
import random
from keras.models import load_model

# create an object of WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# importing the GL Bot corpus file for pre-processing

words=[]
classes = []
documents = []
ignore_words = ['?', '!']
data_file = open("data.json").read()
intents = json.loads(data_file)

# %% [markdown]
# ### Data Pre-Processing

# %%
# preprocessing the json data
# tokenization
#nltk.download('punkt')
#nltk.download('wordnet')
for intent in intents['intents']:
    for pattern in intent['patterns']:

        #tokenize each word
        w = nltk.word_tokenize(pattern)
        words.extend(w)
        #add documents in the corpus
        documents.append((w, intent['tag']))

        # add to our classes list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

# %%
# lemmatize, lower each word and remove duplicates

words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))

# sort classes
classes = sorted(list(set(classes)))

# documents = combination between patterns and intents
print (len(documents), "documents")

# classes = intents
print (len(classes), "classes", classes)

# words = all words, vocabulary
print (len(words), "unique lemmatized words", words)

# creating a pickle file to store the Python objects which we will use while predicting
pickle.dump(words,open('texts.pkl','wb')) 
pickle.dump(classes,open('label.pkl','wb'))
# Out:
# 59 documents
# 10 classes ['asuransi_perjalanan', 'contoh_negara', 'goodbye', 'greeting', 'hospital_search', 'kenapa_harus_ada_asuransi_perjalanan', 'options', 'penjelasan_asuransi', 'pharmacy_search', 'thanks']
# 80 unique lemmatized words ['(', ')', '.', 'a', 'ada', 'apa', 'apakah', 'asuransi', 'bantu', 'bantuin', 'banyak', 'bisa', 'bye', 'byee', 'contoh', 'dadah', 'dah', 'data', 'definisi', 'detail', 'find', 'for', 'good', 'hai', 'hallo', 'halo', 'harus', 'hello', 'helo', 'help', 'hi', 'hii', 'hospital', 'hy', 'hyy', 'i', 'insurance', 'itu', 'jumpa', 'kamu', 'kasih', 'kenapa', 'list', 'locate', 'looking', 'lookup', 'makasih', 'me', 'memiliki', 'nearby', 'negara', 'negaranya', 'ngapain', 'of', 'patient', 'pengertian', 'penjelasan', 'perjalanan', 'pharmacy', 'punya', 'saja', 'sampai', 'saya', 'search', 'searching', 'selamat', 'tentang', 'terima', 'thank', 'thanks', 'tinggal', 'to', 'tolong', 'transfer', 'travel', 'up', 'wajib', 'want', 'yang', 'you']

# %% [markdown]
# ### Creating Training Data

# %%
# create our training data
training = []

# create an empty array for our output
output_empty = [0] * len(classes)

# training set, bag of words for each sentence
for doc in documents:
    # initialize our bag of words
    bag = []
    # list of tokenized words for the pattern
    pattern_words = doc[0]
   
    # lemmatize each word - create base word, in attempt to represent related words
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    
    # create our bag of words array with 1, if word match found in current pattern
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)
    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1
    training.append([bag, output_row])

# shuffle features and converting it into numpy arrays
random.shuffle(training)
training = np.array(training)

# create train and test lists
train_x = list(training[:,0])
train_y = list(training[:,1])

print("Training data created")
# Out:
# Training data created

# %% [markdown]
# ### Creating NN Model

# %%
# Create NN model to predict the responses
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

# Compile model. Stochastic gradient descent with Nesterov accelerated gradient gives good results for this model
sgd = SGD(learning_rate=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

#fitting and saving the model 
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('model.h5', hist) # we will pickle this model to use in the future
print("\n")
print("*"*50)
print("\nModel Created Successfully!")
# Out:
# Epoch 1/200
# 12/12 [==============================] - 0s 2ms/step - loss: 2.2663 - accuracy: 0.2203
# Epoch 2/200
# 12/12 [==============================] - 0s 2ms/step - loss: 2.2212 - accuracy: 0.1864
# Epoch 3/200
# 12/12 [==============================] - 0s 2ms/step - loss: 2.1180 - accuracy: 0.2542
# Epoch 4/200
# 12/12 [==============================] - 0s 2ms/step - loss: 2.1092 - accuracy: 0.2373
# Epoch 5/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.9980 - accuracy: 0.5085
# Epoch 6/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.9357 - accuracy: 0.3559
# Epoch 7/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.7864 - accuracy: 0.4915
# Epoch 8/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.6204 - accuracy: 0.5932
# Epoch 9/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.4831 - accuracy: 0.5763
# Epoch 10/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.4643 - accuracy: 0.5593
# Epoch 11/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.4089 - accuracy: 0.5932
# Epoch 12/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.2409 - accuracy: 0.5593
# Epoch 13/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.1599 - accuracy: 0.7119
# Epoch 14/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.1413 - accuracy: 0.6610
# Epoch 15/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.1034 - accuracy: 0.7119
# Epoch 16/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.8970 - accuracy: 0.7119
# Epoch 17/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.8418 - accuracy: 0.8644
# Epoch 18/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.7431 - accuracy: 0.8136
# Epoch 19/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.7611 - accuracy: 0.7288
# Epoch 20/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.8262 - accuracy: 0.7458
# Epoch 21/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.7470 - accuracy: 0.8136
# Epoch 22/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.6180 - accuracy: 0.7966
# Epoch 23/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.6656 - accuracy: 0.7797
# Epoch 24/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.6553 - accuracy: 0.8475
# Epoch 25/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5479 - accuracy: 0.8475
# Epoch 26/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5179 - accuracy: 0.8475
# Epoch 27/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4332 - accuracy: 0.8814
# Epoch 28/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4044 - accuracy: 0.8644
# Epoch 29/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2745 - accuracy: 0.9492
# Epoch 30/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2768 - accuracy: 0.9492
# Epoch 31/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3482 - accuracy: 0.8983
# Epoch 32/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2965 - accuracy: 0.9831
# Epoch 33/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2666 - accuracy: 0.9153
# Epoch 34/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3508 - accuracy: 0.9153
# Epoch 35/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2005 - accuracy: 0.9322
# Epoch 36/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1866 - accuracy: 0.9831
# Epoch 37/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3058 - accuracy: 0.9153
# Epoch 38/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2486 - accuracy: 0.9492
# Epoch 39/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1126 - accuracy: 1.0000
# Epoch 40/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2521 - accuracy: 0.9153
# Epoch 41/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1969 - accuracy: 0.9661
# Epoch 42/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1704 - accuracy: 0.9831
# Epoch 43/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1856 - accuracy: 0.9661
# Epoch 44/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2129 - accuracy: 0.9322
# Epoch 45/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1273 - accuracy: 1.0000
# Epoch 46/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1718 - accuracy: 0.9661
# Epoch 47/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1227 - accuracy: 0.9661
# Epoch 48/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1284 - accuracy: 0.9831
# Epoch 49/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1871 - accuracy: 0.9492
# Epoch 50/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2778 - accuracy: 0.9153
# Epoch 51/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0810 - accuracy: 1.0000
# Epoch 52/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2386 - accuracy: 0.9492
# Epoch 53/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1251 - accuracy: 0.9492
# Epoch 54/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1713 - accuracy: 0.9661
# Epoch 55/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0744 - accuracy: 0.9831
# Epoch 56/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1618 - accuracy: 0.9661
# Epoch 57/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2021 - accuracy: 0.9322
# Epoch 58/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1119 - accuracy: 0.9661
# Epoch 59/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1345 - accuracy: 0.9831
# Epoch 60/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0899 - accuracy: 0.9831
# Epoch 61/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0528 - accuracy: 1.0000
# Epoch 62/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0616 - accuracy: 1.0000
# Epoch 63/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1102 - accuracy: 0.9831
# Epoch 64/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0724 - accuracy: 1.0000
# Epoch 65/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0929 - accuracy: 0.9831
# Epoch 66/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1041 - accuracy: 0.9831
# Epoch 67/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1112 - accuracy: 0.9661
# Epoch 68/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1336 - accuracy: 0.9661
# Epoch 69/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1409 - accuracy: 0.9661
# Epoch 70/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1524 - accuracy: 0.9831
# Epoch 71/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1021 - accuracy: 0.9661
# Epoch 72/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0427 - accuracy: 1.0000
# Epoch 73/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0595 - accuracy: 0.9831
# Epoch 74/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1246 - accuracy: 0.9492
# Epoch 75/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0826 - accuracy: 0.9661
# Epoch 76/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0916 - accuracy: 0.9661
# Epoch 77/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0289 - accuracy: 1.0000
# Epoch 78/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0507 - accuracy: 1.0000
# Epoch 79/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0298 - accuracy: 1.0000
# Epoch 80/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0356 - accuracy: 1.0000
# Epoch 81/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0598 - accuracy: 1.0000
# Epoch 82/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0337 - accuracy: 1.0000
# Epoch 83/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0490 - accuracy: 1.0000
# Epoch 84/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0364 - accuracy: 1.0000
# Epoch 85/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0528 - accuracy: 1.0000
# Epoch 86/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0230 - accuracy: 1.0000
# Epoch 87/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0664 - accuracy: 0.9831
# Epoch 88/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0391 - accuracy: 1.0000
# Epoch 89/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0281 - accuracy: 1.0000
# Epoch 90/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0476 - accuracy: 1.0000
# Epoch 91/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0449 - accuracy: 1.0000
# Epoch 92/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0882 - accuracy: 0.9831
# Epoch 93/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0399 - accuracy: 1.0000
# Epoch 94/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0715 - accuracy: 0.9831
# Epoch 95/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0723 - accuracy: 1.0000
# Epoch 96/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0349 - accuracy: 1.0000
# Epoch 97/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0462 - accuracy: 0.9831
# Epoch 98/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0432 - accuracy: 0.9831
# Epoch 99/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0502 - accuracy: 0.9831
# Epoch 100/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0561 - accuracy: 1.0000
# Epoch 101/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0406 - accuracy: 1.0000
# Epoch 102/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0142 - accuracy: 1.0000
# Epoch 103/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0507 - accuracy: 1.0000
# Epoch 104/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0160 - accuracy: 1.0000
# Epoch 105/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0394 - accuracy: 1.0000
# Epoch 106/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0245 - accuracy: 1.0000
# Epoch 107/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0642 - accuracy: 0.9661
# Epoch 108/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0160 - accuracy: 1.0000
# Epoch 109/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0256 - accuracy: 1.0000
# Epoch 110/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0201 - accuracy: 1.0000
# Epoch 111/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0708 - accuracy: 0.9831
# Epoch 112/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0375 - accuracy: 1.0000
# Epoch 113/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0198 - accuracy: 1.0000
# Epoch 114/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0736 - accuracy: 0.9661
# Epoch 115/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0409 - accuracy: 0.9831
# Epoch 116/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0443 - accuracy: 1.0000
# Epoch 117/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0542 - accuracy: 0.9831
# Epoch 118/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0201 - accuracy: 1.0000
# Epoch 119/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0580 - accuracy: 0.9661
# Epoch 120/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0748 - accuracy: 0.9661
# Epoch 121/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0702 - accuracy: 0.9831
# Epoch 122/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0286 - accuracy: 1.0000
# Epoch 123/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0099 - accuracy: 1.0000
# Epoch 124/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0393 - accuracy: 1.0000
# Epoch 125/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0623 - accuracy: 0.9831
# Epoch 126/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0163 - accuracy: 1.0000
# Epoch 127/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0325 - accuracy: 1.0000
# Epoch 128/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0220 - accuracy: 1.0000
# Epoch 129/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0344 - accuracy: 0.9831
# Epoch 130/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0724 - accuracy: 0.9831
# Epoch 131/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0573 - accuracy: 0.9661
# Epoch 132/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0174 - accuracy: 1.0000
# Epoch 133/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0449 - accuracy: 1.0000
# Epoch 134/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0091 - accuracy: 1.0000
# Epoch 135/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0424 - accuracy: 0.9831
# Epoch 136/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0720 - accuracy: 0.9831
# Epoch 137/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0414 - accuracy: 0.9831
# Epoch 138/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0262 - accuracy: 1.0000
# Epoch 139/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0072 - accuracy: 1.0000
# Epoch 140/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0498 - accuracy: 0.9831
# Epoch 141/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0724 - accuracy: 0.9831
# Epoch 142/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0442 - accuracy: 0.9831
# Epoch 143/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0368 - accuracy: 1.0000
# Epoch 144/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0200 - accuracy: 1.0000
# Epoch 145/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0248 - accuracy: 1.0000
# Epoch 146/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0072 - accuracy: 1.0000
# Epoch 147/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0594 - accuracy: 0.9831
# Epoch 148/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0219 - accuracy: 1.0000
# Epoch 149/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0293 - accuracy: 1.0000
# Epoch 150/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0132 - accuracy: 1.0000
# Epoch 151/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0313 - accuracy: 1.0000
# Epoch 152/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0400 - accuracy: 0.9831
# Epoch 153/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0141 - accuracy: 1.0000
# Epoch 154/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0195 - accuracy: 1.0000
# Epoch 155/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0470 - accuracy: 0.9831
# Epoch 156/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0818 - accuracy: 0.9831
# Epoch 157/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0500 - accuracy: 0.9831
# Epoch 158/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0206 - accuracy: 1.0000
# Epoch 159/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0210 - accuracy: 1.0000
# Epoch 160/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0326 - accuracy: 0.9831
# Epoch 161/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0151 - accuracy: 1.0000
# Epoch 162/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0327 - accuracy: 0.9831
# Epoch 163/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0152 - accuracy: 1.0000
# Epoch 164/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0436 - accuracy: 0.9831
# Epoch 165/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0140 - accuracy: 1.0000
# Epoch 166/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0289 - accuracy: 0.9831
# Epoch 167/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0146 - accuracy: 1.0000
# Epoch 168/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0220 - accuracy: 1.0000
# Epoch 169/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0377 - accuracy: 1.0000
# Epoch 170/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0183 - accuracy: 1.0000
# Epoch 171/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0192 - accuracy: 1.0000
# Epoch 172/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0253 - accuracy: 1.0000
# Epoch 173/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0227 - accuracy: 1.0000
# Epoch 174/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0450 - accuracy: 0.9661
# Epoch 175/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0048 - accuracy: 1.0000
# Epoch 176/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0202 - accuracy: 1.0000
# Epoch 177/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0332 - accuracy: 1.0000
# Epoch 178/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0194 - accuracy: 1.0000
# Epoch 179/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0539 - accuracy: 0.9831
# Epoch 180/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0165 - accuracy: 1.0000
# Epoch 181/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0556 - accuracy: 0.9831
# Epoch 182/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0382 - accuracy: 0.9831
# Epoch 183/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0071 - accuracy: 1.0000
# Epoch 184/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0148 - accuracy: 1.0000
# Epoch 185/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0136 - accuracy: 1.0000
# Epoch 186/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0103 - accuracy: 1.0000
# Epoch 187/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0174 - accuracy: 1.0000
# Epoch 188/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0426 - accuracy: 0.9831
# Epoch 189/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0200 - accuracy: 1.0000
# Epoch 190/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0118 - accuracy: 1.0000
# Epoch 191/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0149 - accuracy: 1.0000
# Epoch 192/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0139 - accuracy: 1.0000
# Epoch 193/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0083 - accuracy: 1.0000
# Epoch 194/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0126 - accuracy: 1.0000
# Epoch 195/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0240 - accuracy: 1.0000
# Epoch 196/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0217 - accuracy: 1.0000
# Epoch 197/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0243 - accuracy: 0.9831
# Epoch 198/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0465 - accuracy: 0.9831
# Epoch 199/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0171 - accuracy: 1.0000
# Epoch 200/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0297 - accuracy: 0.9831
#
#
# **************************************************
#
# Model Created Successfully!

# %% [raw]
# The accuracy of the model is 99.22 % which is quite impressive.
#
# In the further steps, we will import all the libraries and Train_Bot json data and use the pickled model for the prediction of responses.

# %% [markdown]
# ### Repeating all the above steps and using the pickled model for the prediction of responses

# %%
# load the saved model file
model = load_model('model.h5')
intents = json.loads(open("data.json").read())
words = pickle.load(open('texts.pkl','rb'))
classes = pickle.load(open('label.pkl','rb'))

# %%
def clean_up_sentence(sentence):

    # tokenize the pattern - split words into array
    sentence_words = nltk.word_tokenize(sentence)
    
    # stem each word - create short form for word
    sentence_words = [lemmatizer.lemmatize(word.lower()) for word in sentence_words]
    return sentence_words


# return bag of words array: 0 or 1 for each word in the bag that exists in the sentence

def bow(sentence, words, show_details=True):

    # tokenize the pattern
    sentence_words = clean_up_sentence(sentence)

    # bag of words - matrix of N words, vocabulary matrix
    bag = [0]*len(words) 
    for s in sentence_words:
        for i,w in enumerate(words):
            if w == s: 
               
                # assign 1 if current word is in the vocabulary position
                bag[i] = 1
                if show_details:
                    print ("found in bag: %s" % w)
    return(np.array(bag))

def predict_class(sentence, model):
   
    # filter out predictions below a threshold
    p = bow(sentence, words,show_details=False)
    res = model.predict(np.array([p]))[0]
    error = 0.25
    results = [[i,r] for i,r in enumerate(res) if r>error]
    
    # sort by strength of probability
    results.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    
    for r in results:
        return_list.append({"intent": classes[r[0]], "probability": str(r[1])})
    return return_list

# %%
# function to get the response from the model

def getResponse(ints, intents_json):
    tag = ints[0]['intent']
    list_of_intents = intents_json['intents']
    for i in list_of_intents:
        if(i['tag']== tag):
            result = random.choice(i['responses'])
            break
    return result

# function to predict the class and get the response

def chatbot_response(text):
    ints = predict_class(text, model)
    res = getResponse(ints, intents)
    return res

# %%
# function to start the chat bot which will continue till the user type 'end'

def start_chat():
    print("Bot: This is Sophie! Your Personal Assistant.\n\n")
    while True:
        inp = str(input()).lower()
        if inp.lower()=="end":
            break
        if inp.lower()== '' or inp.lower()== '*':
            print('Please re-phrase your query!')
            print("-"*50)
        else:
            print(f"Bot: {chatbot_response(inp)}"+'\n')
            print("-"*50)

# %% [markdown]
# ## Chatting with BOT using the Command Line Option

# %%
# start the chat bot
start_chat()
# Out:
# Bot: This is Sophie! Your Personal Assistant.
#
#
# Please re-phrase your query!
# --------------------------------------------------
# Please re-phrase your query!
# --------------------------------------------------
# Please re-phrase your query!
# --------------------------------------------------
# Please re-phrase your query!
# --------------------------------------------------
# Bot: Haii, ada yang bisa aku bantu?
#
# --------------------------------------------------
# Bot: Haii, ada yang bisa aku bantu?
#
# --------------------------------------------------
# Please re-phrase your query!
# --------------------------------------------------
# Please re-phrase your query!
# --------------------------------------------------
# Please re-phrase your query!
# --------------------------------------------------
# Please re-phrase your query!
# --------------------------------------------------
# Please re-phrase your query!
# --------------------------------------------------
# Please re-phrase your query!
# --------------------------------------------------
# Please re-phrase your query!
# --------------------------------------------------
# Please re-phrase your query!
# --------------------------------------------------
# Please re-phrase your query!
# --------------------------------------------------
# Please re-phrase your query!
# --------------------------------------------------
# Bot: Haii, ada yang bisa aku bantu?
#
# --------------------------------------------------
# Please re-phrase your query!
# --------------------------------------------------
# Please re-phrase your query!
# --------------------------------------------------
# Please re-phrase your query!
# --------------------------------------------------
# Please re-phrase your query!
# --------------------------------------------------
# Please re-phrase your query!
# --------------------------------------------------
# Please re-phrase your query!
# --------------------------------------------------
# Please re-phrase your query!
# --------------------------------------------------
# Please re-phrase your query!
# --------------------------------------------------
# Please re-phrase your query!
# --------------------------------------------------
# Please re-phrase your query!
# --------------------------------------------------
# Please re-phrase your query!
# --------------------------------------------------
# Please re-phrase your query!
# --------------------------------------------------
# Please re-phrase your query!
# --------------------------------------------------

# %% [markdown]
# ## Chatting with BOT using the Tkinter App
#
# #### **For running the Tkinter GUI you have to download this notebook in ipynb format and run using jupyter notebook in your local machine/pc because in google colab, you cannot run Tkinter apps.**

# %%
import random
import tkinter as tk
from tkinter import *

root=tk.Tk()
filename="Chat Bot"
root.title(f"Chat Bot")
root.geometry('500x400')
root.resizable(False, False)
message=tk.StringVar()

chat_win=Frame(root,bd=1,bg='white',width=50,height=8)
chat_win.place(x=6,y=6,height=300,width=488)

textcon=tk.Text(chat_win,bd=1,bg='white',width=50,height=8)
textcon.pack(fill="both",expand=True)

mes_win=Entry(root,width=30,xscrollcommand=True,textvariable=message)
mes_win.place(x=6,y=310,height=60,width=380)
mes_win.focus()

textcon.config(fg='black')
textcon.tag_config('usr',foreground='black')
textcon.insert(END,"Bot: This is Sophie! Your Personal Assistant.\n\n")
mssg=mes_win.get()

exit_list = ['exit','break','quit','see you later','chat with you later','end the chat','bye','ok bye']

def greet_res(text):
    text=text.lower()
    bot_greet=['hi','hello','hola','hey','howdy']
    usr_greet=['hi','hey','hello','hola','greetings','wassup','whats up']
    for word in text.split():
        if word in usr_greet:
            return random.choice(bot_greet)

def send_msz(event=None):
    usr_input = message.get()
    usr_input = usr_input.lower()
    textcon.insert(END, f'You: {usr_input}'+'\n','usr')
    if usr_input in exit_list:
        textcon.config(fg='black')
        textcon.insert(END,"Bot: Ok bye! Chat with you later\n")
        return root.destroy()
    else:
        textcon.config(fg='black')
        if greet_res(usr_input) != None:
            lab=f"Bot: {greet_res(usr_input)}"+'\n'
            textcon.insert(END,lab)
            mes_win.delete(0,END)
        else:
            lab = f"Bot: {chatbot_response(usr_input)}"+'\n'
            textcon.insert(END,lab)
            mes_win.delete(0,END)

button_send=Button(root,text='Send',bg='dark green',activebackground='grey',command=send_msz,width=12,height=5,font=('Arial'))
button_send.place(x=376,y=310,height=60,width=110)
root.bind('<Return>', send_msz,button_send)
root.mainloop()

# %% [markdown]
# ### END
