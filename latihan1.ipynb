# %% [markdown]
# <a href="https://colab.research.google.com/github/jumadi-cloud/Fundamental-Python/blob/main/latihan1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **ini contoh 1**![Google-Colab.jpg](data:image/jpeg;base64,...)

# %%
print ("Hello Word")
# Out:
# Hello Word

# %% [markdown]
# ini contoh 2

# %%
print("Halo Dunia")
print("Riset Bahasa Python")
# Out:
# Halo Dunia
# Riset Bahasa Python

# %% [markdown]
# ini contoh 3

# %%
bilangan1 = 20
bilangan2 = 10
print(bilangan1 - bilangan2)
# Out:
# 10

# %% [markdown]
# ini contoh 4

# %%
contoh_list = ['Dewi','Budi','Cici','Linda','Cici'] 
print(contoh_list)
contoh_set = {'Dewi','Budi','Cici','Linda','Cici'}
print(contoh_set)
contoh_frozen_set = ({'Dewi','Budi','Cici','Linda','Cici'})
print(contoh_frozen_set)
# Out:
# ['Dewi', 'Budi', 'Cici', 'Linda', 'Cici']
# {'Dewi', 'Cici', 'Linda', 'Budi'}
# {'Dewi', 'Cici', 'Linda', 'Budi'}
