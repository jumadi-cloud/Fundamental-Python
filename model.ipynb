# %%
# import necessary libraries
import warnings
warnings.filterwarnings("ignore")
import nltk
from nltk.stem import WordNetLemmatizer
import json
import pickle

import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import SGD
import random
from keras.models import load_model

# create an object of WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# importing the GL Bot corpus file for pre-processing

words=[]
classes = []
documents = []
ignore_words = ['?', '!']
data_file = open("data.json").read()
intents = json.loads(data_file)

# %%
# preprocessing the json data
# tokenization
#nltk.download('punkt')
#nltk.download('wordnet')
for intent in intents['intents']:
    for pattern in intent['patterns']:

        #tokenize each word
        w = nltk.word_tokenize(pattern)
        words.extend(w)
        #add documents in the corpus
        documents.append((w, intent['tag']))

        # add to our classes list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

# %%
# lemmatize, lower each word and remove duplicates

words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))

# sort classes
classes = sorted(list(set(classes)))

# documents = combination between patterns and intents
print (len(documents), "documents")

# classes = intents
print (len(classes), "classes", classes)

# words = all words, vocabulary
print (len(words), "unique lemmatized words", words)

# creating a pickle file to store the Python objects which we will use while predicting
pickle.dump(words,open('texts.pkl','wb')) 
pickle.dump(classes,open('label.pkl','wb'))
# Out:
# 59 documents
# 10 classes ['asuransi_perjalanan', 'contoh_negara', 'goodbye', 'greeting', 'hospital_search', 'kenapa_harus_ada_asuransi_perjalanan', 'options', 'penjelasan_asuransi', 'pharmacy_search', 'thanks']
# 80 unique lemmatized words ['(', ')', '.', 'a', 'ada', 'apa', 'apakah', 'asuransi', 'bantu', 'bantuin', 'banyak', 'bisa', 'bye', 'byee', 'contoh', 'dadah', 'dah', 'data', 'definisi', 'detail', 'find', 'for', 'good', 'hai', 'hallo', 'halo', 'harus', 'hello', 'helo', 'help', 'hi', 'hii', 'hospital', 'hy', 'hyy', 'i', 'insurance', 'itu', 'jumpa', 'kamu', 'kasih', 'kenapa', 'list', 'locate', 'looking', 'lookup', 'makasih', 'me', 'memiliki', 'nearby', 'negara', 'negaranya', 'ngapain', 'of', 'patient', 'pengertian', 'penjelasan', 'perjalanan', 'pharmacy', 'punya', 'saja', 'sampai', 'saya', 'search', 'searching', 'selamat', 'tentang', 'terima', 'thank', 'thanks', 'tinggal', 'to', 'tolong', 'transfer', 'travel', 'up', 'wajib', 'want', 'yang', 'you']

# %%
# create our training data
training = []

# create an empty array for our output
output_empty = [0] * len(classes)

# training set, bag of words for each sentence
for doc in documents:
    # initialize our bag of words
    bag = []
    # list of tokenized words for the pattern
    pattern_words = doc[0]
   
    # lemmatize each word - create base word, in attempt to represent related words
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    
    # create our bag of words array with 1, if word match found in current pattern
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)
    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1
    training.append([bag, output_row])

# shuffle features and converting it into numpy arrays
random.shuffle(training)
training = np.array(training)

# create train and test lists
train_x = list(training[:,0])
train_y = list(training[:,1])

print("Training data created")
# Out:
# Training data created

# %%
# Create NN model to predict the responses
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

# Compile model. Stochastic gradient descent with Nesterov accelerated gradient gives good results for this model
sgd = SGD(learning_rate=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

#fitting and saving the model 
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('model.h5', hist) # we will pickle this model to use in the future
print("\n")
print("*"*50)
print("\nModel Created Successfully!")
# Out:
# Epoch 1/200
# 12/12 [==============================] - 1s 3ms/step - loss: 2.3345 - accuracy: 0.1017
# Epoch 2/200
# 12/12 [==============================] - 0s 3ms/step - loss: 2.2930 - accuracy: 0.1356
# Epoch 3/200
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1888 - accuracy: 0.2373
# Epoch 4/200
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1406 - accuracy: 0.2542
# Epoch 5/200
# 12/12 [==============================] - 0s 3ms/step - loss: 2.1262 - accuracy: 0.3051
# Epoch 6/200
# 12/12 [==============================] - 0s 4ms/step - loss: 1.9870 - accuracy: 0.4237
# Epoch 7/200
# 12/12 [==============================] - 0s 4ms/step - loss: 1.9483 - accuracy: 0.4407
# Epoch 8/200
# 12/12 [==============================] - 0s 9ms/step - loss: 1.8768 - accuracy: 0.4237
# Epoch 9/200
# 12/12 [==============================] - 0s 7ms/step - loss: 1.8169 - accuracy: 0.4237
# Epoch 10/200
# 12/12 [==============================] - 0s 4ms/step - loss: 1.6741 - accuracy: 0.4237
# Epoch 11/200
# 12/12 [==============================] - 0s 3ms/step - loss: 1.5397 - accuracy: 0.4576
# Epoch 12/200
# 12/12 [==============================] - 0s 4ms/step - loss: 1.2694 - accuracy: 0.6949
# Epoch 13/200
# 12/12 [==============================] - 0s 4ms/step - loss: 1.2763 - accuracy: 0.5593
# Epoch 14/200
# 12/12 [==============================] - 0s 3ms/step - loss: 1.1507 - accuracy: 0.7119
# Epoch 15/200
# 12/12 [==============================] - 0s 4ms/step - loss: 1.1195 - accuracy: 0.5932
# Epoch 16/200
# 12/12 [==============================] - 0s 4ms/step - loss: 1.2329 - accuracy: 0.5763
# Epoch 17/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.9836 - accuracy: 0.7288
# Epoch 18/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.9503 - accuracy: 0.7288
# Epoch 19/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6903 - accuracy: 0.7966
# Epoch 20/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.6295 - accuracy: 0.8475
# Epoch 21/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6567 - accuracy: 0.8136
# Epoch 22/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.6985 - accuracy: 0.7627
# Epoch 23/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.5676 - accuracy: 0.8644
# Epoch 24/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.5330 - accuracy: 0.8644
# Epoch 25/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4883 - accuracy: 0.8644
# Epoch 26/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.5778 - accuracy: 0.8136
# Epoch 27/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.5461 - accuracy: 0.8814
# Epoch 28/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.4154 - accuracy: 0.8983
# Epoch 29/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.4080 - accuracy: 0.8983
# Epoch 30/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4316 - accuracy: 0.8475
# Epoch 31/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3119 - accuracy: 0.9322
# Epoch 32/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3189 - accuracy: 0.8983
# Epoch 33/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.3694 - accuracy: 0.8983
# Epoch 34/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3247 - accuracy: 0.9153
# Epoch 35/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.2262 - accuracy: 0.9322
# Epoch 36/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.2769 - accuracy: 0.9322
# Epoch 37/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2752 - accuracy: 0.9492
# Epoch 38/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2755 - accuracy: 0.9322
# Epoch 39/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.2012 - accuracy: 0.9492
# Epoch 40/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.2721 - accuracy: 0.8814
# Epoch 41/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2323 - accuracy: 0.9153
# Epoch 42/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.2340 - accuracy: 0.9492
# Epoch 43/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1990 - accuracy: 0.9492
# Epoch 44/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2336 - accuracy: 0.9661
# Epoch 45/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2126 - accuracy: 0.9661
# Epoch 46/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0934 - accuracy: 0.9831
# Epoch 47/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1879 - accuracy: 0.9831
# Epoch 48/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1518 - accuracy: 0.9661
# Epoch 49/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1303 - accuracy: 0.9661
# Epoch 50/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2082 - accuracy: 0.9492
# Epoch 51/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1386 - accuracy: 0.9492
# Epoch 52/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1553 - accuracy: 0.9492
# Epoch 53/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1019 - accuracy: 0.9831
# Epoch 54/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1548 - accuracy: 0.9661
# Epoch 55/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1074 - accuracy: 0.9831
# Epoch 56/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1166 - accuracy: 0.9831
# Epoch 57/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0870 - accuracy: 0.9831
# Epoch 58/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1154 - accuracy: 0.9661
# Epoch 59/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0975 - accuracy: 0.9661
# Epoch 60/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0817 - accuracy: 1.0000
# Epoch 61/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1191 - accuracy: 0.9831
# Epoch 62/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1135 - accuracy: 0.9661
# Epoch 63/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2492 - accuracy: 0.9322
# Epoch 64/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1690 - accuracy: 0.9661
# Epoch 65/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1091 - accuracy: 0.9831
# Epoch 66/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0726 - accuracy: 0.9831
# Epoch 67/200
# 12/12 [==============================] - 0s 10ms/step - loss: 0.0681 - accuracy: 1.0000
# Epoch 68/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1689 - accuracy: 0.9661
# Epoch 69/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0832 - accuracy: 0.9831
# Epoch 70/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0751 - accuracy: 0.9831
# Epoch 71/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0789 - accuracy: 0.9661
# Epoch 72/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0903 - accuracy: 0.9831
# Epoch 73/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0581 - accuracy: 1.0000
# Epoch 74/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0950 - accuracy: 1.0000
# Epoch 75/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0830 - accuracy: 0.9661
# Epoch 76/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0252 - accuracy: 1.0000
# Epoch 77/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0475 - accuracy: 1.0000
# Epoch 78/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0710 - accuracy: 1.0000
# Epoch 79/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0618 - accuracy: 1.0000
# Epoch 80/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0559 - accuracy: 1.0000
# Epoch 81/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0394 - accuracy: 1.0000
# Epoch 82/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0616 - accuracy: 0.9831
# Epoch 83/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0814 - accuracy: 0.9831
# Epoch 84/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0581 - accuracy: 0.9831
# Epoch 85/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0555 - accuracy: 0.9831
# Epoch 86/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0400 - accuracy: 1.0000
# Epoch 87/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0669 - accuracy: 1.0000
# Epoch 88/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0322 - accuracy: 1.0000
# Epoch 89/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0922 - accuracy: 0.9831
# Epoch 90/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1516 - accuracy: 0.9661
# Epoch 91/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0376 - accuracy: 1.0000
# Epoch 92/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0558 - accuracy: 0.9831
# Epoch 93/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0496 - accuracy: 0.9831
# Epoch 94/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0775 - accuracy: 0.9661
# Epoch 95/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0604 - accuracy: 1.0000
# Epoch 96/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0989 - accuracy: 0.9661
# Epoch 97/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0387 - accuracy: 1.0000
# Epoch 98/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0262 - accuracy: 1.0000
# Epoch 99/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0888 - accuracy: 0.9492
# Epoch 100/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0666 - accuracy: 0.9831
# Epoch 101/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0327 - accuracy: 1.0000
# Epoch 102/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0694 - accuracy: 0.9661
# Epoch 103/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0315 - accuracy: 0.9831
# Epoch 104/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0215 - accuracy: 1.0000
# Epoch 105/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0322 - accuracy: 1.0000
# Epoch 106/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0175 - accuracy: 1.0000
# Epoch 107/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0116 - accuracy: 1.0000
# Epoch 108/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0439 - accuracy: 1.0000
# Epoch 109/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0313 - accuracy: 0.9831
# Epoch 110/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0977 - accuracy: 0.9661
# Epoch 111/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0204 - accuracy: 1.0000
# Epoch 112/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0119 - accuracy: 1.0000
# Epoch 113/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0211 - accuracy: 1.0000
# Epoch 114/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1346 - accuracy: 0.9831
# Epoch 115/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0452 - accuracy: 1.0000
# Epoch 116/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0562 - accuracy: 0.9831
# Epoch 117/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0335 - accuracy: 1.0000
# Epoch 118/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0344 - accuracy: 1.0000
# Epoch 119/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0328 - accuracy: 0.9831
# Epoch 120/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0271 - accuracy: 0.9831
# Epoch 121/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0262 - accuracy: 1.0000
# Epoch 122/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0520 - accuracy: 0.9831
# Epoch 123/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0815 - accuracy: 0.9831
# Epoch 124/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0279 - accuracy: 1.0000
# Epoch 125/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0189 - accuracy: 1.0000
# Epoch 126/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0537 - accuracy: 0.9831
# Epoch 127/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0325 - accuracy: 1.0000
# Epoch 128/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0241 - accuracy: 1.0000
# Epoch 129/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0214 - accuracy: 1.0000
# Epoch 130/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0341 - accuracy: 1.0000
# Epoch 131/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0883 - accuracy: 0.9831
# Epoch 132/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0247 - accuracy: 1.0000
# Epoch 133/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0179 - accuracy: 1.0000
# Epoch 134/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0222 - accuracy: 1.0000
# Epoch 135/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0346 - accuracy: 1.0000
# Epoch 136/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0269 - accuracy: 1.0000
# Epoch 137/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0597 - accuracy: 0.9831
# Epoch 138/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0189 - accuracy: 1.0000
# Epoch 139/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0558 - accuracy: 0.9831
# Epoch 140/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0408 - accuracy: 0.9831
# Epoch 141/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0346 - accuracy: 1.0000
# Epoch 142/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0238 - accuracy: 1.0000
# Epoch 143/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0236 - accuracy: 1.0000
# Epoch 144/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0295 - accuracy: 1.0000
# Epoch 145/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0596 - accuracy: 0.9831
# Epoch 146/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0485 - accuracy: 0.9831
# Epoch 147/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0176 - accuracy: 1.0000
# Epoch 148/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0084 - accuracy: 1.0000
# Epoch 149/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0284 - accuracy: 0.9831
# Epoch 150/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0226 - accuracy: 1.0000
# Epoch 151/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0238 - accuracy: 1.0000
# Epoch 152/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0159 - accuracy: 1.0000
# Epoch 153/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0322 - accuracy: 0.9831
# Epoch 154/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0452 - accuracy: 1.0000
# Epoch 155/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0450 - accuracy: 0.9831
# Epoch 156/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0372 - accuracy: 0.9831
# Epoch 157/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0777 - accuracy: 0.9831
# Epoch 158/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0684 - accuracy: 0.9661
# Epoch 159/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0611 - accuracy: 0.9831
# Epoch 160/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0482 - accuracy: 0.9831
# Epoch 161/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0099 - accuracy: 1.0000
# Epoch 162/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0353 - accuracy: 0.9831
# Epoch 163/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0576 - accuracy: 1.0000
# Epoch 164/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0217 - accuracy: 1.0000
# Epoch 165/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0124 - accuracy: 1.0000
# Epoch 166/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0236 - accuracy: 1.0000
# Epoch 167/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0249 - accuracy: 1.0000
# Epoch 168/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0098 - accuracy: 1.0000
# Epoch 169/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0162 - accuracy: 1.0000
# Epoch 170/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0156 - accuracy: 1.0000
# Epoch 171/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0082 - accuracy: 1.0000
# Epoch 172/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0204 - accuracy: 1.0000
# Epoch 173/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0076 - accuracy: 1.0000
# Epoch 174/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0190 - accuracy: 1.0000
# Epoch 175/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1139 - accuracy: 0.9661
# Epoch 176/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0361 - accuracy: 1.0000
# Epoch 177/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0482 - accuracy: 0.9831
# Epoch 178/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0297 - accuracy: 1.0000
# Epoch 179/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0624 - accuracy: 0.9831
# Epoch 180/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0152 - accuracy: 1.0000
# Epoch 181/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0414 - accuracy: 1.0000
# Epoch 182/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0450 - accuracy: 0.9831
# Epoch 183/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0555 - accuracy: 0.9831
# Epoch 184/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0071 - accuracy: 1.0000
# Epoch 185/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0193 - accuracy: 1.0000
# Epoch 186/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0133 - accuracy: 1.0000
# Epoch 187/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0176 - accuracy: 1.0000
# Epoch 188/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0774 - accuracy: 0.9831
# Epoch 189/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0540 - accuracy: 0.9831
# Epoch 190/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0309 - accuracy: 1.0000
# Epoch 191/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0249 - accuracy: 1.0000
# Epoch 192/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0180 - accuracy: 1.0000
# Epoch 193/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0171 - accuracy: 1.0000
# Epoch 194/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0189 - accuracy: 1.0000
# Epoch 195/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0455 - accuracy: 0.9831
# Epoch 196/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0301 - accuracy: 0.9831
# Epoch 197/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0141 - accuracy: 1.0000
# Epoch 198/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0182 - accuracy: 1.0000
# Epoch 199/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0354 - accuracy: 1.0000
# Epoch 200/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0760 - accuracy: 0.9831
#
#
# **************************************************
#
# Model Created Successfully!
